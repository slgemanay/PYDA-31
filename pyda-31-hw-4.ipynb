# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

# %%
directories = {
1: ['2207 876234', '11-2'],
2: ['10006'],
3: []
}

# %%
def Pfunction():
    print('Введите номер документа')
    user_input = input()
    for dictionary in documents:
        for key, value in dictionary:
            if user_input == value:
                print(dictionary.get(name))
Pfunction()

# %%
def Sfunction():
    print('Введите номер документа')
    user_input = input()
    for key, value in directories.items():
        if user_input == value:
            print(key)

# %%
def Lfunction():
    for dictionary in documents:
        for key, value in dictionary:
            print(dictionary)
            for key1, value1 in directories:
                if value == value1:
                    print('полка номер ',key1)

# %%
def adsfunction():
    print('Введите номер полки')
    new_shelf = input()
    directories[new_shelf]=''

# %%
def dsfunction():
    print('введите номер полки')
    user_input = input()
    for key, value in directories:
        if value == '':
            del directories[user_input]
        else:
            print('на полке есть документ')

# %%
print('введите команду')
comand = input()
while comand != 'q':
    if comand == 'p':
        Pfunction()
        print('введите команду')
        comand = input()
    elif comand == 's':
        Sfunction()
        print('введите команду')
        comand = input()
    elif comand == 'l':
        Lfunction()
        print('введите команду')
        comand = input()
    elif comand == 'ads':
        adsfunction()
        print('введите команду')
        comand = input()
    elif comand == 'ds':
        dsfunction()
        print('введите команду')
        comand = input()
